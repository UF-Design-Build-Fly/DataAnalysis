# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("airData1.csv")
df2 = pd.read_csv("airData2.csv")
df3 = pd.read_csv("airData3.csv")

# %%
df3
# Out:
#            data          time
# 0      1.318087  1.610919e+09
# 1      1.318087  1.610919e+09
# 2      1.318087  1.610919e+09
# 3      1.314864  1.610919e+09
# 4      1.321309  1.610919e+09
# ...         ...           ...
# 90594  1.272969  1.610921e+09
# 90595  1.314864  1.610921e+09
# 90596  1.314864  1.610921e+09
# 90597  1.279414  1.610921e+09
# 90598  1.314864  1.610921e+09
#
# [90599 rows x 2 columns]

# %%
def moving_average(a, n=50) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n
data1 = df1["data"].to_numpy()
time1 = df1["time"].to_numpy()
#plt.scatter(moving_average(time1[1:10000]), moving_average(data1[1:10000]))
plt.scatter(time1, data1)
plt.show()

# %%
data2 = df2["data"].to_numpy()
time2 = df2[" time"].to_numpy()
plt.scatter(time2, data2)
plt.show()

# %%
data3 = df3["data"].to_numpy()
time3 = df3[" time"].to_numpy()
plt.scatter(time3, data3)
plt.show()
